# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import textwrap

# %%
data_dir = '/Users/annagreene/code/district-comparison/data/'
dist1 = pd.read_csv(data_dir + 'raw/arizonaExample.csv')
mapping = pd.read_csv(data_dir + 'raw/final_mapping.csv')
dist2 = pd.read_csv(data_dir + 'raw/atlantaExample.csv')
replace = [',', '$', '-', '(', ')']
pd.options.mode.chained_assignment = None

# %%
#everything from clean tolleson script
dist1["Object_code"] = 0
dist1["Object_code"] = dist1.Account.str.split(".").str[3]

dist1 = dist1[dist1['Account Type']=="EXPENDITURE"]
dist1 = dist1.drop(columns=['Active', 'Account', 'Description', 'Account Type', 'Budget Control Group', 'Budget', 'Balance', 'Budget Balance', 'Encumbrance', 'Pre Encumbrance', 'Pending Invoices', 'Uncommitted Balance'])

dist1['YTD Transactions'] = dist1['YTD Transactions'].str.translate({ord(x): '' for x in replace}).astype(float)
dist1 = dist1.groupby(['Object_code'])['YTD Transactions'].sum().reset_index()
dist1 = dist1.rename(columns={'YTD Transactions': 'Transactions'})
dist1 = dist1.round(2)

dist1 = dist1.rename(columns={'Object_code': 'Code'})
dist1['Code'] = dist1['Code'].astype(str)
dist1['Code'] = dist1['Code'].str.strip()
display(dist1)
# Out:
#      Code  Transactions
# 0    6000          0.00
# 1    6100          0.00
# 2    6101          0.00
# 3    6103          0.00
# 4    6110       8002.11
# ..    ...           ...
# 181  6890     455508.18
# 182  6891          0.00
# 183  6892          0.00
# 184  6893          0.00
# 185  6899          0.00
#
# [186 rows x 2 columns]

# %%
#everything from clean atlanta script
dist2 = dist2[~dist2.DESCRIPTION.str.contains('TOTAL')]
dist2 = dist2.drop(columns=['Unnamed: 1', 'DESCRIPTION'])
dist2 = dist2.rename(columns={'ACCOUNT': 'Code', ' AMOUNT ': 'Transactions'})

dist2['Code'] = dist2['Code'].str[5:8]
dist2['Code'] = dist2['Code'].astype(str)

dist2['Transactions'] = dist2['Transactions'].str.translate({ord(x): '' for x in replace})
dist2['Transactions'] = np.double(dist2['Transactions'])
dist2 = dist2.groupby(['Code'])['Transactions'].sum().reset_index()
dist2 = dist2.round(2)

display(dist2)
# Out:
#    Code  Transactions
# 0   110  2.254804e+08
# 1   111  1.446570e+05
# 2   112  5.384203e+06
# 3   113  5.684628e+06
# 4   114  5.072093e+05
# ..  ...           ...
# 95  880  2.814457e+06
# 96  881  4.291009e+07
# 97  882  3.109448e+06
# 98  890  3.051903e+06
# 99  930  2.556686e+08
#
# [100 rows x 2 columns]

# %%
#everything from clean mapping script
cols = ["Object_code","Function_code", "Category_Edstruments","Major_Category_Edstruments","Title", "State"]
clean_map = mapping[cols]
clean_map = clean_map.fillna(0)

clean_map["Code"] = ''
clean_map["Code"] = np.where(clean_map["Object_code"] == 0, clean_map["Function_code"], clean_map["Object_code"])
clean_map["Code"] = clean_map["Code"].astype(str)
clean_map["Code"] = clean_map["Code"].str.strip()

clean_map["Major_Category_Edstruments"] = clean_map["Major_Category_Edstruments"].replace('Purchased Professional and Technical Services', 'Professional and Technical Services')
clean_map["Category_Edstruments"] = clean_map["Category_Edstruments"].replace('Purchased Professional Services', 'Professional Services')
clean_map["Category_Edstruments"] = clean_map["Category_Edstruments"].replace('Other Employee Benefits', 'Other Benefits')
clean_map["Category_Edstruments"] = clean_map["Category_Edstruments"].replace('Health Insurance/Health Related Benefits	', 'Health Insurance/Benefits')

#clean_map = clean_map[clean_map["Code"].str.contains('X')==False]
#clean_map["Code"] = clean_map["Code"].astype(str)

display(clean_map)
# Out:
#      Object_code Function_code        Category_Edstruments  \
# 0             10             0           Teachers Salaries
# 1             11             0           Teachers Salaries
# 2             12             0           Teachers Salaries
# 3             14             0           Teachers Salaries
# 4             15             0  Special Education Salaries
# ...          ...           ...                         ...
# 7963         728             0               Miscellaneous
# 7964         729             0               Miscellaneous
# 7965         730             0               Miscellaneous
# 7966         740             0                Debt Service
# 7967         790             0               Miscellaneous
#
#      Major_Category_Edstruments                                      Title  \
# 0                      Salaries                            Regular Teacher
# 1                      Salaries                           Resource Teacher
# ...

# %%
#stuff from map script
mapping = pd.read_csv(data_dir + 'processed/mapping.csv')
dist_1_og = pd.read_csv(data_dir + 'processed/tolleson.csv')
state_1 = 'Arizona'
dist_2_og = pd.read_csv(data_dir + 'processed/atlanta.csv')
state_2 = 'Georgia'

dist_1_map = mapping[mapping['State'] == state_1].reset_index()
dist_1_map = dist_1_map.drop(columns=['index', 'Unnamed: 0', 'Object_code', 'Function_code'])
dist_1_map.loc[len(dist_1_map.index)] = ['Miscellaneous', 'Other Financing Uses', '*Unable to assign to mapping tool*', state_1, 'XXXX']

dist_2_map = mapping[mapping['State'] == state_2].reset_index()
dist_2_map = dist_2_map.drop(columns=['index', 'Unnamed: 0', 'Object_code', 'Function_code'])
dist_2_map.loc[len(dist_2_map.index)] = ['Miscellaneous', 'Other Financing Uses', '*Unable to assign to mapping tool*', state_2, 'XXXX']

dist_1_og['Code'] = dist_1_og['Code'].astype(str)
dist_2_og['Code'] = dist_2_og['Code'].astype(str)

dist_1_merge_diff = dist_1_og.merge(dist_1_map, how='left', on='Code', indicator=True)
dist_1_merge_diff2 = dist_1_merge_diff[dist_1_merge_diff['_merge'] == 'left_only']
dist_1_not_mapped = list(dist_1_merge_diff2['Code'])
dist_1_og['Code'] = np.where(dist_1_og['Code'].isin(dist_1_not_mapped), dist_1_og['Code'] == 'False', dist_1_og['Code'])

dist_2_merge_diff = dist_2_og.merge(dist_2_map, how='left', on='Code', indicator=True)
dist_2_merge_diff2 = dist_2_merge_diff[dist_2_merge_diff['_merge'] == 'left_only']
dist_2_not_mapped = list(dist_2_merge_diff2['Code'])
dist_2_og['Code'] = np.where(dist_2_og['Code'].isin(dist_2_not_mapped), dist_2_og['Code'] == 'False', dist_2_og['Code'])

dist_1_og.loc[(dist_1_og.Code == False),'Code']='XXXX'
dist_1_og = dist_1_og.groupby(['Code'])['Transactions'].sum().reset_index()

dist_2_og.loc[(dist_2_og.Code == False),'Code']='XXXX'
dist_2_og = dist_2_og.groupby(['Code'])['Transactions'].sum().reset_index()

dist_1_merge = dist_1_og.merge(dist_1_map, how='left', on='Code')
dist_1_merge['district'] = 'Tolleson'

dist_2_merge = dist_2_map.merge(dist_2_og, how='left', on='Code')
dist_2_merge['district'] = 'Atlanta'

dist_2_merge
# Out:
#            Category_Edstruments Major_Category_Edstruments  \
# 0             Teachers Salaries                   Salaries
# 1    Special Education Salaries                   Salaries
# 2    Special Education Salaries                   Salaries
# 3    Special Education Salaries                   Salaries
# 4    Special Education Salaries                   Salaries
# ..                          ...                        ...
# 149               Miscellaneous       Other Financing Uses
# 150               Miscellaneous       Other Financing Uses
# 151               Miscellaneous       Other Financing Uses
# 152               Miscellaneous       Other Financing Uses
# 153               Miscellaneous       Other Financing Uses
#
#                                                  Title    State  Code  \
# 0                                             TEACHERS  Georgia   110
# 1                  Preschool Special Education Teacher  Georgia   141
# ...

# %%
#making datasets from make graphics scripts
palette = ['#559C6C', '#9F8EA1', '#6ABBA1', '#3E9AE3', '#B9ABBF', '#90D8D1', '#B1D6E7', '#D4C8DF', '#C1F4FA', '#CB91BD', '#EFE7FF', '#8BD8F1', '#4F86C9', '#D0CCF1', '#5BBAEB', '#D1B8CA', '#ADB3E4', '#857383', '#849BD7', '#857383', '#3e9ae3', '#b1d6e7', '#4f86c9', '#CB91BD', '#559c6c', '#d1b8ca']

dist_1_subcategories = dist_1_merge.groupby("Category_Edstruments")['Transactions'].sum().reset_index()
dist_1_len = len(dist_1_subcategories.index)
palette = palette[:dist_1_len]
dist_1_subcategories['palette'] = palette
dist_1_subcategories['Per Pupil'] = dist_1_subcategories['Transactions']/11956
dist_1_subcategories = dist_1_subcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_1_subcategories['district'] = 'Tolleson'

dist_1_other = dist_1_subcategories[10:]['Per Pupil'].sum()
dist_1_subcategories_pie = dist_1_subcategories[:10]
dist_1_subcategories_pie.loc[len(dist_1_subcategories_pie.index)] = ['Other', 0, dist_1_other, '#ADB3E4', 'Tolleson']
dist_1_subcategories_pie = dist_1_subcategories_pie.sort_values(by = 'Per Pupil', ascending = False )

dist_1_majorcategories = dist_1_merge.groupby("Major_Category_Edstruments")['Transactions'].sum().reset_index()
dist_1_majorcategories['Per Pupil'] = dist_1_majorcategories['Transactions']/11956
dist_1_majorcategories = dist_1_majorcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_1_majorcategories['district'] = 'Tolleson'

dist_2_subcategories = dist_2_merge.groupby("Category_Edstruments")['Transactions'].sum().reset_index()
dist_2_len = len(dist_2_subcategories.index)
palette = palette[:dist_2_len]
dist_2_subcategories['palette'] = palette
dist_2_subcategories['Per Pupil'] = dist_2_subcategories['Transactions']/52000
dist_2_subcategories = dist_2_subcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_2_subcategories['district'] = 'Atlanta'

dist_2_other = dist_2_subcategories[10:]['Per Pupil'].sum()
dist_2_subcategories_pie = dist_2_subcategories[:10]
dist_2_subcategories_pie.loc[len(dist_2_subcategories_pie.index) + 1] = ['Other', 0, dist_2_other, '#ADB3E4', 'Atlanta']
dist_2_subcategories_pie = dist_2_subcategories_pie.sort_values(by = 'Per Pupil', ascending = False )

dist_2_majorcategories = dist_2_merge.groupby("Major_Category_Edstruments")['Transactions'].sum().reset_index()
dist_2_majorcategories['Per Pupil'] = dist_2_majorcategories['Transactions']/52000
dist_2_majorcategories = dist_2_majorcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_2_majorcategories['district'] = 'Atlanta'

dists_sub = [dist_1_subcategories, dist_2_subcategories]
subcategories = pd.concat(dists_sub)

subcategories_indicator = subcategories.groupby("Category_Edstruments")['Per Pupil'].sum().reset_index()
subcategories_indicator = subcategories_indicator.rename(columns={'Per Pupil': 'Sort'})
subcategories = subcategories.merge(subcategories_indicator)
subcategories = subcategories.sort_values(by="Sort",ascending = False)

dists_major = [dist_1_majorcategories, dist_2_majorcategories]
majorcategories = pd.concat(dists_major)

majorcategories_indicator = majorcategories.groupby("Major_Category_Edstruments")['Per Pupil'].sum().reset_index()
majorcategories_indicator = majorcategories_indicator.rename(columns={'Per Pupil': 'Sort'})
majorcategories = majorcategories.merge(majorcategories_indicator)
majorcategories = majorcategories.reindex([0, 1, 4, 5, 12, 13, 2, 3, 8, 9, 10, 11, 6, 7])

dist_2_subcategories
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-ca2e0379a456> in <module>
#      13 dist_1_subcategories_pie = dist_1_subcategories[:10]
#      14 dist_1_subcategories_pie.loc[len(dist_1_subcategories_pie.index)] = ['Other', 0, dist_1_other, '#ADB3E4', 'Tolleson']
# ---> 15 dist_1_subcategories_pie = dist_1_subcategories_pie.sort_values(by = 'Per Pupil', ascending = False )
#      16
#      17 dist_1_majorcategories = dist_1_merge.groupby("Major_Category_Edstruments")['Transactions'].sum().reset_index()
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5463
#    5464             indexer = nargsort(
# -> 5465                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5466             )
#    5467
#
# ...

# %%
palette=dist_1_subcategories_pie["palette"]
sizes=dist_1_subcategories_pie["Per Pupil"]/11956

fig1, ax1 = plt.subplots(figsize=(7, 7))

patches, texts, autotexts = ax1.pie(sizes, labels=dist_1_subcategories_pie["Category_Edstruments"], autopct='%1.1f%%',
    shadow=False, startangle=0, colors=palette, normalize=True, labeldistance=1.05, pctdistance=.9)

for text in texts:
    text.set_size(12.5)
for autotext in autotexts:
    autotext.set_color('black')
    #autotext.set_weight('bold')
    autotext.set_size(10)
    
ax1.axis('equal')
#ax1.set_title(district_1.capitalize() + ": Ten Largest Spending Categories", fontsize=25)
ax1
# Out:
# <AxesSubplot:>

# %%
#anna bar graph from make graphics
sns.set_theme(style="ticks")
palette = sns.color_palette(["#89C9DC","#CB91BD"], 2)
plt.figure(figsize=(21.17, 10.58))

test = sns.barplot(
    data=majorcategories, x='Major_Category_Edstruments', y='Per Pupil', hue="district", palette=palette)

test.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('${x:,.0f}'))

plt.yticks(size=18,)
plt.xticks(size=18,)

for p in test.patches:
    test.annotate(format(p.get_height(), ',.0f'), (p.get_x() + p.get_width() / 2, p.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points', size=15)

test.set_title('Per-Pupil Expenditure Across Aggregated Categories', fontsize=40, y=1.02)
sns.despine()
test.tick_params(bottom=False)
plt.xlabel('Major Categories', fontsize=25)
plt.ylabel('Per-Pupil Expenditure', fontsize=25)
test.set_xticklabels([textwrap.fill(e, 16) for e in majorcategories['Major_Category_Edstruments'][::2]])
test.legend(bbox_to_anchor=(1.00, 1.00), loc=2, borderaxespad=0., prop={"size":18})

# %%
#pie chart
subsorted = dist_1_subcategories.sort_values(by="Per Pupil",ascending = False).head(7)
palette=['#1787e0',  '#857383',  '#b1d6e7', '#4f86c9', '#CB91BD', '#559c6c', '#f11fb7']
sizes = subsorted["Per Pupil"]/11956

fig1, ax1 = plt.subplots(figsize=(7, 7))

patches, texts, autotexts = ax1.pie(sizes, labels=subsorted["Category_Edstruments"], autopct='%1.1f%%',
        shadow=False, startangle=-10, explode=[.01]*7, colors=palette, normalize=True, labeldistance=1.06, pctdistance=.8)

for text in texts:
    text.set_size(12.5)
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_weight('bold')
    autotext.set_size(13)
    
ax1.axis('equal')
ax1.set_title("Tolleson School District: 7 Largest Spending Categories", fontsize=14)
#plt.savefig("subpiechart.png")
plt.show()

# %%
sns.set_theme(style="ticks")
palette = sns.color_palette(["#89C9DC","#CB91BD"], 2)
plt.figure(figsize=(10, 6))

test = sns.barplot(
    data=subcategories.head(14), y='Category_Edstruments', x='Per Pupil', hue="district", palette=palette
)

plt.yticks(
#    rotation=60, 
    horizontalalignment='right',
)

test.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('${x:,.0f}'))

for p in test.patches:
    width = p.get_width()
    plt.text(260+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:,.0f}'.format(width), ha='center', va='center')

test.set_title('Per-Pupil Expenditure Across Sub Categories', fontsize=20, y=1.01)
sns.despine()
test.tick_params(bottom=False)
plt.ylabel('')
plt.xlabel('Per-Pupil Expenditure', fontsize=15)
test.legend(bbox_to_anchor=(.93, .96), loc=2, borderaxespad=0.)

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]

data = [225, 90, 50, 60, 100, 5]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
palette = ['#559C6C', '#9F8EA1', '#6ABBA1', '#3E9AE3', '#B9ABBF', '#90D8D1', '#B1D6E7', '#D4C8DF', '#C1F4FA', '#CB91BD', '#EFE7FF', '#8BD8F1', '#4F86C9', '#D0CCF1', '#5BBAEB', '#D1B8CA', '#ADB3E4', '#857383', '#849BD7', '#857383', '#3e9ae3', '#b1d6e7', '#4f86c9', '#CB91BD', '#559c6c', '#d1b8ca', '#5BBAEB', '#D0CCF1']

dist_1_subcategories = dist_1_merge.groupby("Category_Edstruments")['Transactions'].sum().reset_index()
dist_1_subcategories['Per Pupil'] = dist_1_subcategories['Transactions']/11956
dist_1_len = len(dist_1_subcategories.index)
palette_1 = palette[:dist_1_len]
dist_1_subcategories['palette'] = palette_1
#dist_1_subcategories = dist_1_subcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_1_subcategories['district'] = 'Tolleson'
    
dist_1_other = dist_1_subcategories[10:]['Per Pupil'].sum()
dist_1_subcategories_pie = dist_1_subcategories[:10]
dist_1_subcategories_pie.loc[len(dist_1_subcategories_pie.index)] = ['Other', 0, dist_1_other, '#ADB3E4', 'Tolleson']
dist_1_subcategories_pie = dist_1_subcategories_pie.sort_values(by = 'Per Pupil', ascending = False )

dist_1_majorcategories = dist_1_merge.groupby("Major_Category_Edstruments")['Transactions'].sum().reset_index()
dist_1_majorcategories['Per Pupil'] = dist_1_majorcategories['Transactions']/11956
dist_1_majorcategories = dist_1_majorcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_1_majorcategories['district'] = 'Tolleson'

dist_2_subcategories = dist_2_merge.groupby("Category_Edstruments")['Transactions'].sum().reset_index()
dist_2_subcategories['Per Pupil'] = dist_2_subcategories['Transactions']/52000
#dist_2_len = len(dist_2_subcategories.index)
#palette_2 = palette[:dist_2_len]
dist_2_subcategories['palette'] = palette
dist_2_subcategories = dist_2_subcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_2_subcategories['district'] = 'Atlanta'

dist_2_other = dist_2_subcategories[10:]['Per Pupil'].sum()
dist_2_subcategories_pie = dist_2_subcategories[:10]
dist_2_subcategories_pie.loc[len(dist_2_subcategories_pie.index) + 1] = ['Other', 0, dist_2_other, '#ADB3E4', 'Atlanta']
dist_2_subcategories_pie = dist_2_subcategories_pie.sort_values(by = 'Per Pupil', ascending = False )

dist_2_majorcategories = dist_2_merge.groupby("Major_Category_Edstruments")['Transactions'].sum().reset_index()
dist_2_majorcategories['Per Pupil'] = dist_2_majorcategories['Transactions']/52000
dist_2_majorcategories = dist_2_majorcategories.sort_values(by = 'Per Pupil', ascending = False )
dist_2_majorcategories['district'] = 'Atlanta'

dists_sub = [dist_1_subcategories, dist_2_subcategories]
subcategories = pd.concat(dists_sub)

subcategories_indicator = subcategories.groupby("Category_Edstruments")['Per Pupil'].sum().reset_index()
subcategories_indicator = subcategories_indicator.rename(columns={'Per Pupil': 'Sort'})
subcategories = subcategories.merge(subcategories_indicator)
subcategories = subcategories.sort_values(by="Sort",ascending = False)

dists_major = [dist_1_majorcategories, dist_2_majorcategories]
majorcategories = pd.concat(dists_major)

majorcategories_indicator = majorcategories.groupby("Major_Category_Edstruments")['Per Pupil'].sum().reset_index()
majorcategories_indicator = majorcategories_indicator.rename(columns={'Per Pupil': 'Sort'})
majorcategories = majorcategories.merge(majorcategories_indicator)
majorcategories = majorcategories.reindex([0, 1, 4, 5, 12, 13, 2, 3, 8, 9, 10, 11, 6, 7])

dist_2_merge.loc[dist_2_merge['Category_Edstruments'] == 'Miscellaneous']
# Out:
#     Category_Edstruments Major_Category_Edstruments  \
# 84         Miscellaneous       Other Financing Uses
# 85         Miscellaneous       Other Financing Uses
# 107        Miscellaneous       Other Financing Uses
# 108        Miscellaneous       Other Financing Uses
# 109        Miscellaneous       Other Financing Uses
# 112        Miscellaneous       Other Financing Uses
# 138        Miscellaneous       Other Financing Uses
# 139        Miscellaneous       Other Financing Uses
# 140        Miscellaneous       Other Financing Uses
# 141        Miscellaneous       Other Financing Uses
# 142        Miscellaneous       Other Financing Uses
# 143        Miscellaneous       Other Financing Uses
# 144        Miscellaneous       Other Financing Uses
# 145        Miscellaneous       Other Financing Uses
# 146        Miscellaneous       Other Financing Uses
# 147        Miscellaneous       Other Financing Uses
# 148        Miscellaneous       Other Financing Uses
# ...

# %%
dist_1_subcategories
# Out:
#          Category_Edstruments  Transactions    Per Pupil  palette  district
# 0     Administrative Salaries    7148896.09   597.933765  #559C6C  Tolleson
# 1                   Buildings   40056983.52  3350.366638  #9F8EA1  Tolleson
# 2       Busing/Transportation     116900.19     9.777533  #6ABBA1  Tolleson
# 3                Debt Service   12446855.20  1041.055135  #3E9AE3  Tolleson
# 4                        Food    2353527.29   196.849054  #B9ABBF  Tolleson
# 5   Health Insurance/Benefits     886208.48    74.122489  #90D8D1  Tolleson
# 6    Instructional Curriculum    1117899.95    93.501167  #B1D6E7  Tolleson
# 7                        Land     262635.83    21.966864  #D4C8DF  Tolleson
# 8     Machinery and Equipment   12095406.44  1011.659957  #C1F4FA  Tolleson
# 9           Maintenance Costs    2203059.20   184.263901  #CB91BD  Tolleson
# 10              Miscellaneous    2497087.32   208.856417  #EFE7FF  Tolleson
# ...

# %%
data_dir = '/Users/annagreene/code/district-comparison/data/'
district_data = pd.read_csv(data_dir + 'processed/district_data.csv', low_memory=False)
district_1 = 408490
district_data
# Out:
# (1.0, '21ST CENTURY CYBER CS', 'Pennsylvania', 'PENNSYLVANIA', 'PA ', '4200091', '13369', '13233', '42', '95', '13036', '6674', '21st Century Cyber CS', 'Chester County', '42', '1', '1', '1', '126 Wallace Ave.', 'Downingtown', '19335', '7-Independent Charter District', '21-Suburb: Large', '1-Open', 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '37980', 'Philadelphia-Reading-Camden, PA-NJ-DE-MD', '428', '40.0108', '-75.704371', 'PA-124150002', '4206', '1-Metropolitan Area', 'Charter district which is an LEA for programs authorized under IDEA but not under ESEA and Perkins', 'High', '6th Grade', '12th Grade', '1235', '3', '205', '178', '34', '212', '-', '349', '886', '-', '-', '-', '-', '-', '-', '-', '73', '115', '161', '256', '214', '257', '159', '-', '-', '-', '486', '749', '486', '749', '4', '18', '97', '128', '918', '0', '70', '1235', '1', '3', '7', '11', '36', '61', '52', '76', '368', '550', '0', '0', '22', '48', '1', '3', '7', '11', '36', '61', '52', '76', '368', '550', '0', '0
# ...

# %%
dist_2_merge.loc[dist_2_merge['nces_schoolID'] == district_1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nces_schoolID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-a2f340f91614> in <module>
# ...
