# %%
import pandas as pd

# %%
data_dir = '/Users/annagreene/code/district-comparison/data/'

# %%
mapping = pd.read_csv(data_dir + 'final_mapping.csv')
raw_dist = pd.read_csv(data_dir + 'raw/arizonaExample.csv')
# Out:
#        Active                         Account                Description  \
# 0        True  001.000.0000.0100.000.000. 002                       CASH
# 1        True  001.000.0000.0100.000.000.0000                       CASH
# 2        True  001.000.0000.0102.000.000.0000               CASH IN BANK
# 3        True  001.000.0000.0103.000.000.0000  CASH ON DEP/COUNTY TREASR
# 4        True  001.000.0000.0144.000.000.0000                      STATE
# ...       ...                             ...                        ...
# 64642    True  965.630.1000.6221.202.000.0000      SOCIAL SECURITY-OASDI
# 64643    True  965.630.1000.6222.202.000.0000                   MEDICARE
# 64644    True  965.630.1000.6231.202.000.0000           STATE RETIREMENT
# 64645    True  965.630.1000.6232.202.000.0000       LONG-TERM DISABILITY
# 64646    True  965.630.1000.6260.202.000.0000      WORKERS' COMPENSATION
#
#       Account Type Budget Control Group Budget YTD Transactions  \
# 0            ASSET                  NaN  $0.00            $0.00
# 1            ASSET                  NaN  $0.00            $0.00
# 2            ASSET                  NaN  $0.00            $0.00
# 3            ASSET                  NaN  $0.00   $63,322,851.07
# 4            ASSET                  NaN  $0.00            $0.00
# ...            ...                  ...    ...              ...
# 64642  EXPENDITURE                  NaN  $0.00            $0.00
# 64643  EXPENDITURE                  NaN  $0.00            $0.00
# 64644  EXPENDITURE                  NaN  $0.00            $0.00
# 64645  EXPENDITURE                  NaN  $0.00            $0.00
# 64646  EXPENDITURE                  NaN  $0.00            $0.00
#
#                  Balance Encumbrance     Budget Balance Pre Encumbrance  \
# 0                  $0.00       $0.00              $0.00           $0.00
# 1                  $0.00       $0.00              $0.00           $0.00
# 2                  $0.00       $0.00              $0.00           $0.00
# 3      -($63,322,851.07)       $0.00  -($63,322,851.07)           $0.00
# 4                  $0.00       $0.00              $0.00           $0.00
# ...                  ...         ...                ...             ...
# 64642              $0.00       $0.00              $0.00           $0.00
# 64643              $0.00       $0.00              $0.00           $0.00
# 64644              $0.00       $0.00              $0.00           $0.00
# 64645              $0.00       $0.00              $0.00           $0.00
# 64646              $0.00       $0.00              $0.00           $0.00
#
#       Pending Invoices Uncommitted Balance
# 0                $0.00               $0.00
# 1                $0.00               $0.00
# 2                $0.00               $0.00
# 3                $0.00   -($63,322,851.07)
# 4                $0.00               $0.00
# ...                ...                 ...
# 64642            $0.00               $0.00
# 64643            $0.00               $0.00
# 64644            $0.00               $0.00
# 64645            $0.00               $0.00
# 64646            $0.00               $0.00
#
# [64647 rows x 13 columns]

# %%
raw_dist["Object_code"] = 0
raw_dist["Object_code"] = raw_dist.Account.str.split(".").str[3]
dist = raw_dist[raw_dist['Account Type']=="EXPENDITURE"]
dist = dist.drop(columns=['Active', 'Account', 'Description', 'Account Type', 'Budget Control Group', 'Budget', 'Budget Balance','Balance', 'Encumbrance', 'Pre Encumbrance', 'Pending Invoices', 'Uncommitted Balance'])

# %%
dist
# Out:
#       YTD Transactions Object_code
# 70               $0.00        6626
# 73               $0.00        6113
# 74               $0.00        6100
# 75               $0.00        6100
# 76               $0.00        6100
# ...                ...         ...
# 64642            $0.00        6221
# 64643            $0.00        6222
# 64644            $0.00        6231
# 64645            $0.00        6232
# 64646            $0.00        6260
#
# [57691 rows x 2 columns]
